# %%
#set up the environment
# %pip install alpha_vantage pandas matplotlib scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: alpha_vantage in c:\users\josh\appdata\roaming\python\python312\site-packages (3.0.0)
# Requirement already satisfied: pandas in c:\users\josh\appdata\roaming\python\python312\site-packages (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\josh\appdata\roaming\python\python312\site-packages (3.10.0)
# Requirement already satisfied: scikit-learn in c:\users\josh\appdata\roaming\python\python312\site-packages (1.6.0)
# Requirement already satisfied: aiohttp in c:\users\josh\appdata\roaming\python\python312\site-packages (from alpha_vantage) (3.11.0)
# Requirement already satisfied: requests in c:\users\josh\appdata\roaming\python\python312\site-packages (from alpha_vantage) (2.32.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\josh\appdata\roaming\python\python312\site-packages (from pandas) (2.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\josh\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\josh\appdata\roaming\python\python312\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\josh\appdata\roaming\python\python312\site-packages (from pandas) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\josh\appdata\roaming\python\python312\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\josh\appdata\roaming\python\python312\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\josh\appdata\roaming\python\python312\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\josh\appdata\roaming\python\python312\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\josh\appdata\roaming\python\python312\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\josh\appdata\roaming\python\python312\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\josh\appdata\roaming\python\python312\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\josh\appdata\roaming\python\python312\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\josh\appdata\roaming\python\python312\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\josh\appdata\roaming\python\python312\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\josh\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\josh\appdata\roaming\python\python312\site-packages (from aiohttp->alpha_vantage) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\josh\appdata\roaming\python\python312\site-packages (from aiohttp->alpha_vantage) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\josh\appdata\roaming\python\python312\site-packages (from aiohttp->alpha_vantage) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\josh\appdata\roaming\python\python312\site-packages (from aiohttp->alpha_vantage) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\josh\appdata\roaming\python\python312\site-packages (from aiohttp->alpha_vantage) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\josh\appdata\roaming\python\python312\site-packages (from aiohttp->alpha_vantage) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\josh\appdata\roaming\python\python312\site-packages (from aiohttp->alpha_vantage) (1.17.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\josh\appdata\roaming\python\python312\site-packages (from requests->alpha_vantage) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\josh\appdata\roaming\python\python312\site-packages (from requests->alpha_vantage) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\josh\appdata\roaming\python\python312\site-packages (from requests->alpha_vantage) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\josh\appdata\roaming\python\python312\site-packages (from requests->alpha_vantage) (2024.8.30)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#import personal API key
# %pip install python-dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: python-dotenv in c:\users\josh\appdata\roaming\python\python312\site-packages (1.0.1)

# %%
#import the libraries
from alpha_vantage.timeseries import TimeSeries
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Alpha Vantage Personal API Key
from dotenv import load_dotenv
import os

# Load environment variables from the .env file
load_dotenv()

# Access the API key
api_key = os.getenv('ALPHA_VANTAGE_API_KEY')

# %%
# Initialize the TimeSeries object
ts = TimeSeries(key=api_key, output_format='pandas')

# Fetch daily stock data for AMD (any symbol works!)
data, meta_data = ts.get_daily(symbol='AMD', outputsize='full')

# Display the first few rows of the dataset
data.head()
# Out:
#             1. open   2. high  3. low  4. close   5. volume
# date
# 2024-12-27   124.37  126.1800  122.26    125.19  32924011.0
# 2024-12-26   125.52  127.2999  125.05    125.06  25139138.0
# 2024-12-24   127.51  127.5100  124.66    126.29  24829564.0
# 2024-12-23   120.71  126.3387  120.47    124.60  47777898.0
# 2024-12-20   118.00  121.8600  117.90    119.21  53591212.0

# %%
# Save AMD stock data to a CSV file
data.to_csv('AMD_stock_data.csv')

# %%
# Plot the closing prices for AMD
data['4. close'].plot(title='AMD Closing Prices', figsize=(10, 6))
plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')
plt.grid()
plt.show()
